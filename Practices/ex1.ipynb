# %% [markdown]
# # Первый computational notebook

# %% [markdown]
# ## Упражнение: Вычисление числа pi с помощью метода Монте-Карло

# %% [markdown]
# 1. Создайте новый блокнот , назовите его и добавьте заголовок (ячейку в формате
# markdown ниже).

# %% [markdown]
# # Вычисление числа pi с помощью метода Монте - Карло

# %% [markdown]
# 2. Зафиксируйте соответствующие формулы в новой ячейке (ячейке с Markdown):

# %% [markdown]
# - Площадь квадрата: $S = (2 R)^2$
# - Площадь круга: $C = \pi R^2$
# - $C/S = (\pi R^2)/(4R^2) = \pi /4$
# - $\pi = 4 * C/S$

# %% [markdown]
# 3. Добавьте изображение для пояснения концепции (ячейка markdown):

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# 4. Импортируйте два модуля, которые нам понадобятся (ячейка с кодом):

# %%
# !python -m pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\mishanyasha\appdata\local\programs\python\python313\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mishanyasha\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\mishanyasha\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mishanyasha\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\mishanyasha\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\mishanyasha\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.1.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\mishanyasha\appdata\roaming\python\python313\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\mishanyasha\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\mishanyasha\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mishanyasha\appdata\roaming\python\python313\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\mishanyasha\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import random
import matplotlib.pyplot as plt

# %% [markdown]
# 5. Инициализируйте количество точек (ячейка с кодом):

# %%
num_points = 10000

# %% [markdown]
# 6. Броски дротиков (ячейка с кодом):

# %%
points = []
hits = 0
for _ in range (num_points):
    x, y = random.random(), random.random()
    if x*x + y*y < 1.0:
        hits += 1
        points.append((x,y, "black"))
    else:
        points.append((x,y, "magenta"))

# %% [markdown]
# 7. Построение графика результатов (ячейка с кодом):

# %%
x, y, colors = zip(*points)

fig, ax = plt.subplots()
fig.set_size_inches(7.0, 7.0)

ax.scatter(x, y, c=colors)

# %% [markdown]
# 8. Вычислите оценку для pi (ячейка с кодом):

# %%
fraction = hits / num_points
4 * fraction
# Out:
# 3.142

# %% [markdown]
# ## Блокноты и контроль версий

# %% [markdown]
# ### Упражнение: что происходит без `requirements.txt`?

# %%
# !python -m pip install -r requirements.txt
# Out:
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %% [markdown]
# ### Добавление виджета в задание 1

# %%
# !python -m pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in c:\users\mishanyasha\appdata\local\programs\python\python313\lib\site-packages (8.1.5)
# Requirement already satisfied: comm>=0.1.3 in c:\users\mishanyasha\appdata\roaming\python\python313\site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\mishanyasha\appdata\roaming\python\python313\site-packages (from ipywidgets) (8.29.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\mishanyasha\appdata\roaming\python\python313\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\mishanyasha\appdata\local\programs\python\python313\lib\site-packages (from ipywidgets) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\mishanyasha\appdata\local\programs\python\python313\lib\site-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: decorator in c:\users\mishanyasha\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\mishanyasha\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\mishanyasha\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\mishanyasha\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\mishanyasha\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\mishanyasha\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: colorama in c:\users\mishanyasha\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\mishanyasha\appdata\roaming\python\python313\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\mishanyasha\appdata\roaming\python\python313\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\mishanyasha\appdata\roaming\python\python313\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\mishanyasha\appdata\roaming\python\python313\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\mishanyasha\appdata\roaming\python\python313\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\mishanyasha\appdata\roaming\python\python313\site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from matplotlib import pyplot
import random
from ipywidgets import interact, widgets

# %matplotlib inline


def throw_darts(num_points):
    points = []
    hits = 0
    for _ in range(num_points):
        x, y = random.random(), random.random()
        if x*x + y*y < 1.0:
            hits += 1
            points.append((x, y, True))
        else:
            points.append((x, y, False))
    fraction = hits / num_points
    pi = 4 * fraction
    return pi, points


def create_plot(points):
    x, y, colors = zip(*points)
    pyplot.scatter(x, y, c=colors)


def experiment(num_points):
    pi, points = throw_darts(num_points)
    create_plot(points)
    print("approximation:", pi)

# %%
interact(experiment, num_points=widgets.IntSlider(min=100, max=10000, step=100, value=10000))
# Out:
# interactive(children=(IntSlider(value=10000, description='num_points', max=10000, min=100, step=100), Output()…
# <function __main__.experiment(num_points)>
